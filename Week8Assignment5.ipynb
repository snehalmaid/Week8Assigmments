# %%
import pandas as pd
import numpy as np

# %%
file1 = pd.read_csv("C:\\Users\\User\\Downloads\\datasets\\gradedata.csv")

# %%
file1.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
file1.take(np.random.permutation(len(file1))[:100])
# Out:
#         fname      lname  gender  age  exercise  hours  grade  \
# 1416   Dillon     Fowler    male   16         2      8   80.6
# 1309   Odette   Jacobson  female   18         3     14   88.3
# 94    Bernard  Mcconnell    male   14         2     10   78.3
# 661   Camille       Barr  female   14         4     14  100.0
# 1326  Abraham     Snider    male   16         1      4   73.3
# ...       ...        ...     ...  ...       ...    ...    ...
# 1464    Lilah     Cooley  female   18         3     13   93.5
# 897      Inga    Ellison  female   19         5     13   93.9
# 1493  Leonard     Juarez    male   19         1     11   79.7
# 1573    Linda     Moreno  female   15         3      3   61.7
# 422      Dara      Weber  female   15         3     11   85.7
#
#                                             address
# 1416       7882 Fairground St., Hermitage, TN 37076
# 1309         179 Hawthorne Dr., Fullerton, CA 92831
# 94                 571 Acacia St., Smyrna, GA 30080
# ...
